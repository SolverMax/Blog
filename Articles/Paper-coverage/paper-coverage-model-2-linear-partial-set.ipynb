# %% [markdown]
# # Paper coverage, Model 2
#
# Linear model. Selects from a list of candidate paper sizes, where the candidates are the item sizes. We select a given number of candidates to minimize total weighted waste.
#
# Since the list of candidates is only a fraction of the possible size combinations, the solutions are almost certainly sub-optimal. However, it turns out that the solutions are fairly good.

# %%
# %run ./components/imports.ipynb
# %run ./components/utilities.ipynb
# %run ./components/solver.ipynb
# %run ./components/data-model-2.ipynb
# %run ./components/formulation-model-2.ipynb
# %run ./components/output-model-2.ipynb
# %run ./components/main-model-2.ipynb

# %%
# Globals

# Data assumptions
ProductsMin = 6   # >= 1
ProductsMax = 6   # <= number of items
DataFile = os.path.join(os.getcwd() + '\data', 'data-100-actual-sorted.xlsx')
DataWorksheet = 'Data'

# Run options
Verbose = False
LoadSolution = True
TimeLimit = 3600   # seconds

# Solver options
Neos = False
SolverName = 'appsi_highs'
os.environ['NEOS_EMAIL'] = 'your-email@company.com'

# Model file
WriteFile = False
ModelFile = 'model-2.gams'

# Fixed
ModelName = 'Paper coverage - Model 2'
Checkpoints = []   # List of time checkpoints

# %%
Main()
# Out:
# Paper coverage - Model 2, Order size 6
#
# Order size:   6
# Objective:    69,318 (2.0% of baseline)
# Products:     [   962    654    822    554    842    594    862    596    898    596   1006    768 ]
#     962x654  822x554  842x594  862x596  898x596  1006x768      Item
# 0         0        0        1        0        0         0   762x564
# 1         0        0        1        0        0         0   834x438
# 2         1        0        0        0        0         0   962x650
# 3         1        0        0        0        0         0   962x652
# 4         1        0        0        0        0         0   942x654
# 5         1        0        0        0        0         0   962x654
# 6         0        1        0        0        0         0   632x548
# 7         0        0        1        0        0         0   632x588
# 8         0        0        0        0        0         1   958x660
# 9         0        0        0        0        0         1   962x660
# ...
