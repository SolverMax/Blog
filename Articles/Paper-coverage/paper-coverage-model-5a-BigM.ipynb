# %% [markdown]
# # Paper coverage, Model 5a
#
# Source: https://www.reddit.com/r/excel/comments/16ht8m1/require_improved_optimized_solution/
#
# Variation of Model 3, with rotation of products. Single Big M for all items.

# %%
# %run ./components/imports.ipynb
# %run ./components/utilities.ipynb
# %run ./components/solver.ipynb
# %run ./components/data-model-5a-full.ipynb
# %run ./components/formulation-model-5a.ipynb
# %run ./components/output-model-2.ipynb
# %run ./components/main-model-2.ipynb

# %%
# Globals

# Data assumptions
ProductsMin = 6   # >= 1
ProductsMax = 6   # <= number of items
DataFile = os.path.join(os.getcwd() + '\data', 'data-20-unsorted.xlsx')
DataWorksheet = 'Data'

# Run options
Verbose = True
LoadSolution = True
TimeLimit = 3600   # seconds
Iterations = 1
ExtraCandidates = 0

# Solver options
Neos = False
SolverName = 'appsi_highs'
os.environ['NEOS_EMAIL'] = 'your-email@company.com'

# Model file
WriteFile = True
ModelFile = 'model-5a.gams'

# Fixed
ModelName = 'Paper coverage - Model 5a'
Checkpoints = []   # List of time checkpoints

# %%
Main()
# Out:
# Paper coverage - Model 5a, Order size 6
# Presolving model
# 24101 rows, 25220 cols, 169280 nonzeros
# 24099 rows, 17625 cols, 84532 nonzeros
# 16500 rows, 15918 cols, 68538 nonzeros
# 13257 rows, 13000 cols, 51083 nonzeros
# 10631 rows, 10635 cols, 36826 nonzeros
# 9080 rows, 10238 cols, 33333 nonzeros
#
# Solving MIP model with:
#    9080 rows
#    10238 cols (10237 binary, 1 integer, 0 implied int., 0 continuous)
#    33333 nonzeros
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
#      Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -164768.364     inf                  inf        0      0      0         0     8.4s
#  R       0       0         0   0.00%   27945.8065      143330.982        80.50%        0      0      0      1906     8.6s
#  C       0       0         0   0.00%   28442.6985      91839.454         69.03%       75     22      0      2067     9.2s
#  L       0       0         0   0.00%   28913.781       28913.781          0.00%      214     49      0      2662    14.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      28913.781
#   Dual bound        28913.781
#   Gap               0% (tolerance: 0.01%)
#   Solution status   feasible
#                     28913.781 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            14.22 (total)
#                     8.35 (presolve)
#                     0.00 (postsolve)
#   Nodes             1
#   LP iterations     2857 (total)
#                     0 (strong br.)
#                     756 (separation)
#                     195 (heuristics)
#
# Order size:   6
# Objective:    28,914 (17.55% of baseline)
# Products:     [   704    825    142    675    874   1000    243    825    845    330    939    532 ]
#     704x825  142x675  874x1000  243x825  845x330  939x532      Item
# 0         0        0         1        0        0        0  782x1000
# 1         0        0         0        1        0        0   231x541
# 2         0        0         0        0        0        1   784x532
# 3         0        0         0        0        0        1   817x490
# 4         1        0         0        0        0        0   704x730
# 5         0        1         0        0        0        0   129x399
# 6         0        1         0        0        0        0   115x486
# 7         0        1         0        0        0        0   442x141
# 8         0        0         0        1        0        0   807x214
# 9         0        1         0        0        0        0   142x675
# 10        0        0         1        0        0        0   874x982
# 11        0        0         0        0        1        0   669x330
# 12        0        0         0        1        0        0   243x825
# 13        0        0         0        0        1        0   571x287
# 14        0        0         0        0        1        0   308x845
# 15        1        0         0        0        0        0   621x825
# 16        1        0         0        0        0        0   658x772
# 17        0        0         1        0        0        0   729x899
# 18        0        0         0        0        0        1   915x489
# 19        0        0         0        0        0        1   504x939
# Checkpoint    Seconds
# ---------------------
# Setup             0.0
# Solved           25.9
# Finish           25.9
