# %% [markdown]
# ### Paper coverage, Model 5b
#
# Source: https://www.reddit.com/r/excel/comments/16ht8m1/require_improved_optimized_solution/
#
# Variation of Model 3, with rotation of products. Individual Big M for each item.

# %%
# %run ./components/imports.ipynb
# %run ./components/utilities.ipynb
# %run ./components/solver.ipynb
# %run ./components/data-model-5b-full.ipynb
# %run ./components/formulation-model-5b.ipynb
# %run ./components/output-model-2.ipynb
# %run ./components/main-model-2.ipynb

# %%
# Globals

# Data assumptions
ProductsMin = 6   # >= 1
ProductsMax = 6   # <= number of items
DataFile = os.path.join(os.getcwd() + '\data', 'data-20-unsorted.xlsx')
DataWorksheet = 'Data'

# Run options
Verbose = True
LoadSolution = True
TimeLimit = 3600   # seconds
Iterations = 1
ExtraCandidates = 0

# Solver options
Neos = False
SolverName = 'appsi_highs'
os.environ['NEOS_EMAIL'] = 'your-email@company.com'

# Model file
WriteFile = True
ModelFile = 'model-5b.gams'

# Fixed
ModelName = 'Paper coverage - Model 5b'
Checkpoints = []   # List of time checkpoints

# %%
Main()
# Out:
# Paper coverage - Model 5b, Order size 6
# Presolving model
# 24101 rows, 25220 cols, 169280 nonzeros
# 13096 rows, 11203 cols, 41318 nonzeros
# 10031 rows, 10213 cols, 34277 nonzeros
# 9080 rows, 10161 cols, 33262 nonzeros
#
# Solving MIP model with:
#    9080 rows
#    10161 cols (10160 binary, 1 integer, 0 implied int., 0 continuous)
#    33262 nonzeros
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
#      Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -164768.364     inf                  inf        0      0      0         0     5.2s
#  R       0       0         0   0.00%   27945.8065      118400.929        76.40%        0      0      0      1927     5.4s
#  C       0       0         0   0.00%   28366.5155      102921.56         72.44%       50     14      0      2040     6.0s
# ...
